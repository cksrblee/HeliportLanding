# %%
import cv2

cap = cv2.VideoCapture("./Source.mp4")

# %%
import os
if not cap.isOpened():
    print("error")
    exit(0)
    
length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

print("length :", length)
print("width :", width)
print("height :", height)
print("fps :", fps)

count = 0

while(cap.isOpened()):
    ret, image = cap.read()
    if(int(cap.get(1)) % fps == 0): #앞서 불러온 fps 값을 사용하여 1초마다 추출
        cv2.imwrite("./data/heliport/frame%d.jpg" % count, image)
        print('Saved frame number :', str(int(cap.get(1))))
        count += 1
        
cap.release()
# Out:
# length : 9973
# width : 1280
# height : 800
# fps : 30.0
# Saved frame number : 30
# Saved frame number : 60
# Saved frame number : 90
# Saved frame number : 120
# Saved frame number : 150
# Saved frame number : 180
# Saved frame number : 210
# Saved frame number : 240
# Saved frame number : 270
# Saved frame number : 300
# Saved frame number : 330
# Saved frame number : 360
# Saved frame number : 390
# Saved frame number : 420
# Saved frame number : 450
# Saved frame number : 480
# Saved frame number : 510
# Saved frame number : 540
# Saved frame number : 570
# Saved frame number : 600
# Saved frame number : 630
# Saved frame number : 660
# Saved frame number : 690
# Saved frame number : 720
# Saved frame number : 750
# Saved frame number : 780
# Saved frame number : 810
# Saved frame number : 840
# Saved frame number : 870
# Saved frame number : 900
# Saved frame number : 930
# Saved frame number : 960
# Saved frame number : 990
# Saved frame number : 1020
# Saved frame number : 1050
# Saved frame number : 1080
# Saved frame number : 1110
# Saved frame number : 1140
# Saved frame number : 1170
# Saved frame number : 1200
# Saved frame number : 1230
# Saved frame number : 1260
# Saved frame number : 1290
# Saved frame number : 1320
# Saved frame number : 1350
# Saved frame number : 1380
# Saved frame number : 1410
# Saved frame number : 1440
# Saved frame number : 1470
# Saved frame number : 1500
# Saved frame number : 1530
# Saved frame number : 1560
# Saved frame number : 1590
# Saved frame number : 1620
# Saved frame number : 1650
# Saved frame number : 1680
# Saved frame number : 1710
# Saved frame number : 1740
# Saved frame number : 1770
# Saved frame number : 1800
# Saved frame number : 1830
# Saved frame number : 1860
# Saved frame number : 1890
# Saved frame number : 1920
# Saved frame number : 1950
# Saved frame number : 1980
# Saved frame number : 2010
# Saved frame number : 2040
# Saved frame number : 2070
# Saved frame number : 2100
# Saved frame number : 2130
# Saved frame number : 2160
# Saved frame number : 2190
# Saved frame number : 2220
# Saved frame number : 2250
# Saved frame number : 2280
# Saved frame number : 2310
# Saved frame number : 2340
# Saved frame number : 2370
# Saved frame number : 2400
# Saved frame number : 2430
# Saved frame number : 2460
# Saved frame number : 2490
# Saved frame number : 2520
# Saved frame number : 2550
# Saved frame number : 2580
# Saved frame number : 2610
# Saved frame number : 2640
# Saved frame number : 2670
# Saved frame number : 2700
# Saved frame number : 2730
# Saved frame number : 2760
# Saved frame number : 2790
# Saved frame number : 2820
# Saved frame number : 2850
# Saved frame number : 2880
# Saved frame number : 2910
# Saved frame number : 2940
# Saved frame number : 2970
# Saved frame number : 3000
# Saved frame number : 3030
# Saved frame number : 3060
# Saved frame number : 3090
# Saved frame number : 3120
# Saved frame number : 3150
# Saved frame number : 3180
# Saved frame number : 3210
# Saved frame number : 3240
# Saved frame number : 3270
# Saved frame number : 3300
# Saved frame number : 3330
# Saved frame number : 3360
# Saved frame number : 3390
# Saved frame number : 3420
# Saved frame number : 3450
# Saved frame number : 3480
# Saved frame number : 3510
# Saved frame number : 3540
# Saved frame number : 3570
# Saved frame number : 3600
# Saved frame number : 3630
# Saved frame number : 3660
# Saved frame number : 3690
# Saved frame number : 3720
# Saved frame number : 3750
# Saved frame number : 3780
# Saved frame number : 3810
# Saved frame number : 3840
# Saved frame number : 3870
# Saved frame number : 3900
# Saved frame number : 3930
# Saved frame number : 3960
# Saved frame number : 3990
# Saved frame number : 4020
# Saved frame number : 4050
# Saved frame number : 4080
# Saved frame number : 4110
# Saved frame number : 4140
# Saved frame number : 4170
# Saved frame number : 4200
# Saved frame number : 4230
# Saved frame number : 4260
# Saved frame number : 4290
# Saved frame number : 4320
# Saved frame number : 4350
# Saved frame number : 4380
# Saved frame number : 4410
# Saved frame number : 4440
# Saved frame number : 4470
# Saved frame number : 4500
# Saved frame number : 4530
# Saved frame number : 4560
# Saved frame number : 4590
# Saved frame number : 4620
# Saved frame number : 4650
# Saved frame number : 4680
# Saved frame number : 4710
# Saved frame number : 4740
# Saved frame number : 4770
# Saved frame number : 4800
# Saved frame number : 4830
# Saved frame number : 4860
# Saved frame number : 4890
# Saved frame number : 4920
# Saved frame number : 4950
# Saved frame number : 4980
# Saved frame number : 5010
# Saved frame number : 5040
# Saved frame number : 5070
# Saved frame number : 5100
# Saved frame number : 5130
# Saved frame number : 5160
# Saved frame number : 5190
# Saved frame number : 5220
# Saved frame number : 5250
# Saved frame number : 5280
# Saved frame number : 5310
# Saved frame number : 5340
# Saved frame number : 5370
# Saved frame number : 5400
# Saved frame number : 5430
# Saved frame number : 5460
# Saved frame number : 5490
# Saved frame number : 5520
# Saved frame number : 5550
# Saved frame number : 5580
# Saved frame number : 5610
# Saved frame number : 5640
# Saved frame number : 5670
# Saved frame number : 5700
# Saved frame number : 5730
# Saved frame number : 5760
# Saved frame number : 5790
# Saved frame number : 5820
# Saved frame number : 5850
# Saved frame number : 5880
# Saved frame number : 5910
# Saved frame number : 5940
# Saved frame number : 5970
# Saved frame number : 6000
# Saved frame number : 6030
# Saved frame number : 6060
# Saved frame number : 6090
# Saved frame number : 6120
# Saved frame number : 6150
# Saved frame number : 6180
# Saved frame number : 6210
# Saved frame number : 6240
# Saved frame number : 6270
# Saved frame number : 6300
# Saved frame number : 6330
# Saved frame number : 6360
# Saved frame number : 6390
# Saved frame number : 6420
# Saved frame number : 6450
# Saved frame number : 6480
# Saved frame number : 6510
# Saved frame number : 6540
# Saved frame number : 6570
# Saved frame number : 6600
# Saved frame number : 6630
# Saved frame number : 6660
# Saved frame number : 6690
# Saved frame number : 6720
# Saved frame number : 6750
# Saved frame number : 6780
# Saved frame number : 6810
# Saved frame number : 6840
# Saved frame number : 6870
# Saved frame number : 6900
# Saved frame number : 6930
# Saved frame number : 6960
# Saved frame number : 6990
# Saved frame number : 7020
# Saved frame number : 7050
# Saved frame number : 7080
# Saved frame number : 7110
# Saved frame number : 7140
# Saved frame number : 7170
# Saved frame number : 7200
# Saved frame number : 7230
# Saved frame number : 7260
# Saved frame number : 7290
# Saved frame number : 7320
# Saved frame number : 7350
# Saved frame number : 7380
# Saved frame number : 7410
# Saved frame number : 7440
# Saved frame number : 7470
# Saved frame number : 7500
# Saved frame number : 7530
# Saved frame number : 7560
# Saved frame number : 7590
# Saved frame number : 7620
# Saved frame number : 7650
# Saved frame number : 7680
# Saved frame number : 7710
# Saved frame number : 7740
# Saved frame number : 7770
# Saved frame number : 7800
# Saved frame number : 7830
# Saved frame number : 7860
# Saved frame number : 7890
# Saved frame number : 7920
# Saved frame number : 7950
# Saved frame number : 7980
# Saved frame number : 8010
# Saved frame number : 8040
# Saved frame number : 8070
# Saved frame number : 8100
# Saved frame number : 8130
# Saved frame number : 8160
# Saved frame number : 8190
# Saved frame number : 8220
# Saved frame number : 8250
# Saved frame number : 8280
# Saved frame number : 8310
# Saved frame number : 8340
# Saved frame number : 8370
# Saved frame number : 8400
# Saved frame number : 8430
# Saved frame number : 8460
# Saved frame number : 8490
# Saved frame number : 8520
# Saved frame number : 8550
# Saved frame number : 8580
# Saved frame number : 8610
# Saved frame number : 8640
# Saved frame number : 8670
# Saved frame number : 8700
# Saved frame number : 8730
# Saved frame number : 8760
# Saved frame number : 8790
# Saved frame number : 8820
# Saved frame number : 8850
# Saved frame number : 8880
# Saved frame number : 8910
# Saved frame number : 8940
# Saved frame number : 8970
# Saved frame number : 9000
# Saved frame number : 9030
# Saved frame number : 9060
# Saved frame number : 9090
# Saved frame number : 9120
# Saved frame number : 9150
# Saved frame number : 9180
# Saved frame number : 9210
# Saved frame number : 9240
# Saved frame number : 9270
# Saved frame number : 9300
# Saved frame number : 9330
# Saved frame number : 9360
# Saved frame number : 9390
# Saved frame number : 9420
# Saved frame number : 9450
# Saved frame number : 9480
# Saved frame number : 9510
# Saved frame number : 9540
# Saved frame number : 9570
# Saved frame number : 9600
# Saved frame number : 9630
# Saved frame number : 9660
# Saved frame number : 9690
# Saved frame number : 9720
# Saved frame number : 9750
# Saved frame number : 9780
# Saved frame number : 9810
# Saved frame number : 9840
# Saved frame number : 9870
# Saved frame number : 9900
# Saved frame number : 9930
# Saved frame number : 9960
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-97165930da14> in <module>
#      17
#      18 while(cap.isOpened()):
# ---> 19     ret, image = cap.read()
#      20     if(int(cap.get(1)) % fps == 0): #앞서 불러온 fps 값을 사용하여 1초마다 추출
#      21         cv2.imwrite("./data/heliport/frame%d.jpg" % count, image)
#
# KeyboardInterrupt:
